# %%
#please save the data into csv file
df_complete.to_csv('titanic_complete.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Random forest imputing values
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor as rf
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
from sklearn.impute import SimpleImputer
df=sns.load_dataset('titanic')
df.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %%
# remove deck column
df.drop('deck',axis=1, inplace=True)
#check missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
from sklearn.preprocessing import LabelEncoder
#CREATE A LABELENCODER object using LabelEncoder() in for loop for categorical columns
# columns to encode
columns_to_encode = ['sex', 'embarked', 'who', 'class', 'embark_town', 'alive']
#dictionary to store labelencoder for each column
label_encoder = {}
for col in columns_to_encode:
    #create a new labelencoder for the column
    le = LabelEncoder()
    # fit and transform the data
    df[col] = le.fit_transform(df[col])
    #store the encoder in the dictionary
    label_encoder[col] = le

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2      2    1
# 1         1       1    0  38.0      1      0  71.2833         0      0    2
# 2         1       3    0  26.0      0      0   7.9250         2      2    2
# 3         1       1    0  35.0      1      0  53.1000         2      0    2
# 4         0       3    1  35.0      0      0   8.0500         2      2    1
#
#    adult_male  embark_town  alive  alone
# 0        True            2      0  False
# 1       False            0      1  False
# 2       False            2      1   True
# 3       False            2      1  False
# 4        True            2      0   True

# %%
#we have to first impute the missing values in the aGE column before we can use it to predict the missing values
#split the dataset into two parts:one with missing values, one without
df_with_missing = df[df['age'].isna()]
#dropna removes all values with missing values
df_without_missing = df.dropna()

# %%
print("The shape of the original dataset is:",df.shape)
print("The shape of the dataset with missing values removed is:", df_with_missing.shape)
print("The shape of the dataset without missing values removed is:", df_without_missing.shape)
# Out:
# The shape of the original dataset is: (891, 14)
# The shape of the dataset with missing values removed is: (177, 14)
# The shape of the dataset without missing values removed is: (714, 14)

# %%
df_with_missing.head()
# Out:
#     survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 5          0       3    1  NaN      0      0   8.4583         1      2    1
# 17         1       2    1  NaN      0      0  13.0000         2      1    1
# 19         1       3    0  NaN      0      0   7.2250         0      2    2
# 26         0       3    1  NaN      0      0   7.2250         0      2    1
# 28         1       3    0  NaN      0      0   7.8792         1      2    2
#
#     adult_male  embark_town  alive  alone
# 5         True            1      0   True
# 17        True            2      1   True
# 19       False            0      1   True
# 26        True            0      0   True
# 28       False            1      1   True

# %%
df_without_missing.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2      2    1
# 1         1       1    0  38.0      1      0  71.2833         0      0    2
# 2         1       3    0  26.0      0      0   7.9250         2      2    2
# 3         1       1    0  35.0      1      0  53.1000         2      0    2
# 4         0       3    1  35.0      0      0   8.0500         2      2    1
#
#    adult_male  embark_town  alive  alone
# 0        True            2      0  False
# 1       False            0      1  False
# 2       False            2      1   True
# 3       False            2      1  False
# 4        True            2      0   True

# %%
#check the names of the columns
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
#regression imputation
#split the data into x and y and we will take only the columns with no missing values
X = df_without_missing.drop(['age'],axis=1)
y = df_without_missing['age']
#split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)
#randomforest imputation
rf_model = RandomForestRegressor(n_estimators = 100, random_state=42)
rf_model.fit(X_train, y_train)
#evaluate the model
y_pred = rf_model.predict(X_test)
print("RMSE random forest imputation:", np.sqrt(mean_squared_error(y_test,y_pred)))
print("R2 score for random forest imputation:", r2_score(y_test,y_pred))
print("MAE random forest imputation:", mean_absolute_error(y_test,y_pred))
print("MAPE random forest imputation:", mean_absolute_percentage_error(y_test,y_pred))
# Out:
# RMSE random forest imputation: 11.081260589808045
# R2 score for random forest imputation: 0.33769388288226154
# MAE random forest imputation: 8.666661815622195
# MAPE random forest imputation: 0.40839466096086574

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# age            177
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
y_pred = rf_model.predict(df_with_missing.drop(['age'], axis=1))

# %%
y_pred # predicted missing values
# Out:
# array([32.97658333, 35.64221825, 18.347     , 35.57148611, 20.65142857,
#        26.7619855 , 36.648     , 18.63142857, 21.80633333, 33.55618169,
#        31.06587652, 35.90741667, 18.63142857, 24.824     , 31.03      ,
#        39.405     , 25.849     , 26.7619855 , 31.06587652, 19.41142857,
#        31.06587652, 31.06587652, 26.7619855 , 26.27095821, 29.23514286,
#        31.06587652, 48.25650595, 27.94      , 31.87071429, 31.99628481,
#        30.015     , 20.85816667, 33.755     , 60.19168831, 26.00185714,
#        26.24316667, 28.91733333, 49.31      , 28.55277778, 48.25650595,
#        18.63142857, 20.85816667, 33.78929167, 26.7619855 , 26.63      ,
#        32.01066667, 28.22883333, 28.55277778, 31.99628481, 29.72904762,
#        48.25650595, 27.67733333, 56.26333333, 18.63142857, 34.65645944,
#        60.44168831, 39.405     , 35.7725    , 18.63142857, 24.78266667,
#        34.305     , 31.06587652, 31.602     , 20.85816667, 25.296     ,
#        36.97133333, 26.7619855 , 24.85777778, 55.52      , 35.57148611,
#        20.65142857, 20.65142857, 35.90741667, 18.001     , 18.63142857,
#        39.47333333, 26.7619855 , 30.16908333, 26.63      , 26.7619855 ,
#        24.02805952, 34.65645944, 29.42072422, 33.55618169, 31.99628481,
#        48.25650595, 24.85777778, 23.11209163, 24.83533333, 31.06587652,
#        38.22933333, 48.25650595, 31.06587652, 34.65645944, 30.16908333,
#        31.99628481, 47.13      , 34.65645944, 26.63      , 24.83533333,
#        23.08233333, 26.63047619, 23.518125  , 40.09880556, 31.06587652,
#        34.95423214, 35.57148611, 26.96691667, 27.47      , 26.96691667,
#        28.        , 23.78047619, 29.70866667, 37.26078571, 26.547     ,
#        48.25650595, 31.06587652, 29.42072422, 26.96691667, 18.63142857,
#        27.61883333, 32.55166667, 31.06587652, 27.513375  , 33.66772547,
#        35.57148611, 26.7619855 , 43.55      , 26.58728571, 28.55277778,
#        48.25650595, 30.16908333, 41.999     , 26.988     , 29.31457143,
#        35.71033333, 26.7619855 , 20.92142857, 26.7619855 , 29.13884783,
#        38.22933333, 34.65645944, 25.32811441, 29.31457143, 16.876     ,
#        25.849     , 57.97458028, 30.42173214, 16.876     , 34.65645944,
#        26.7619855 , 26.7619855 , 64.9625    , 23.78047619, 45.39      ,
#        34.30619444, 35.57148611, 48.25650595, 30.16908333, 34.02      ,
#        48.25650595, 26.24316667, 54.35      , 41.999     , 25.02884524,
#        30.97725   , 29.83383333, 26.96691667, 31.06587652, 36.72      ,
#        20.85816667, 37.63666667, 26.96691667, 26.24316667, 24.81692641,
#        26.7619855 , 32.61      ])

# %%
#remove warnings
import warnings
warnings.filterwarnings('ignore')
#replace the missing values with predicted values
df_with_missing['age'] = y_pred
#check the missing values
df_with_missing.isnull().sum().sort_values(ascending=False)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
#concatenate the two dataframes
df_complete = pd.concat([df_with_missing,df_without_missing], axis=0)
#print the shape of the complete dataframe
print("the shape of the complete dataframe is:", df_complete.shape)
df_complete.head()
# Out:
# the shape of the complete dataframe is: (891, 14)
#     survived  pclass  sex        age  sibsp  parch     fare  embarked  class  \
# 5          0       3    1  32.976583      0      0   8.4583         1      2
# 17         1       2    1  35.642218      0      0  13.0000         2      1
# 19         1       3    0  18.347000      0      0   7.2250         0      2
# 26         0       3    1  35.571486      0      0   7.2250         0      2
# 28         1       3    0  20.651429      0      0   7.8792         1      2
#
#     who  adult_male  embark_town  alive  alone
# 5     1        True            1      0   True
# 17    1        True            2      1   True
# 19    2       False            0      1   True
# 26    1        True            0      0   True
# 28    2       False            1      1   True

# %%
#from sklearn.preprocessing import LabelEncoder
for col in columns_to_encode:
    #retreive the coresponding labelencoder for column
    le = label_encoder[col]
    #inverse transform of the data
    df_complete[col] = label_encoder[col].inverse_transform(df_complete[col])
    # check the first 5 rows of complete dataframe
    df_complete.head()

# %%
df_complete.head()
# Out:
#     survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 5          0       3    male  32.976583      0      0   8.4583        Q
# 17         1       2    male  35.642218      0      0  13.0000        S
# 19         1       3  female  18.347000      0      0   7.2250        C
# 26         0       3    male  35.571486      0      0   7.2250        C
# 28         1       3  female  20.651429      0      0   7.8792        Q
#
#      class    who  adult_male  embark_town alive  alone
# 5    Third    man        True   Queenstown    no   True
# 17  Second    man        True  Southampton   yes   True
# 19   Third  woman       False    Cherbourg   yes   True
# 26   Third    man        True    Cherbourg    no   True
# 28   Third  woman       False   Queenstown   yes   True

# %%
#print the shape of complete data frame
print("The shape of the complete dataframe is :", df_complete.shape)
# Out:
# The shape of the complete dataframe is : (891, 14)

# %%
#check the numbers of the missing values in each column
df_complete.isnull().sum().sort_values(ascending=False)
# Out:
# embarked       2
# embark_town    2
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# class          0
# who            0
# adult_male     0
# alive          0
# alone          0
# dtype: int64
